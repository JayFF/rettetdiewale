# %%
import pandas as pd
import numpy as np
import bokeh as bk
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv', sep=',', quoting=3, error_bad_lines=False)
df
# Out:
# Skipping line 19: expected 122 fields, saw 134
# Skipping line 20: expected 122 fields, saw 152
# Skipping line 21: expected 122 fields, saw 140
# Skipping line 22: expected 122 fields, saw 134
# Skipping line 23: expected 122 fields, saw 134
# Skipping line 24: expected 122 fields, saw 146
# Skipping line 25: expected 122 fields, saw 146
# Skipping line 26: expected 122 fields, saw 140
# Skipping line 27: expected 122 fields, saw 140
# Skipping line 28: expected 122 fields, saw 140
# Skipping line 29: expected 122 fields, saw 140
# Skipping line 30: expected 122 fields, saw 140
# Skipping line 31: expected 122 fields, saw 146
# Skipping line 32: expected 122 fields, saw 140
# Skipping line 33: expected 122 fields, saw 146
# Skipping line 34: expected 122 fields, saw 140
# Skipping line 35: expected 122 fields, saw 146
# Skipping line 36: expected 122 fields, saw 140
# Skipping line 37: expected 122 fields, saw 140
# Skipping line 38: expected 122 fields, saw 140
# ...
