# %%
import pandas as pd
from prepare_wahldaten import wahlergebnis_recent

# %%
data = wahlergebnis_recent("btw17_kerg.csv")

# %%
data
# Out:
#         Nr                                             Gebiet  gehört zu  \
# 1      1.0                              Flensburg – Schleswig        1.0
# 2      2.0                  Nordfriesland – Dithmarschen Nord        1.0
# 3      3.0                       Steinburg – Dithmarschen Süd        1.0
# 4      4.0                              Rendsburg-Eckernförde        1.0
# 5      5.0                                               Kiel        1.0
# 6      6.0                                  Plön – Neumünster        1.0
# 7      7.0                                          Pinneberg        1.0
# 8      8.0                          Segeberg – Stormarn-Mitte        1.0
# 9      9.0                        Ostholstein – Stormarn-Nord        1.0
# 10    10.0                 Herzogtum Lauenburg – Stormarn-Süd        1.0
# 11    11.0                                             Lübeck        1.0
# 12     1.0                                 Schleswig-Holstein       99.0
# ...

# %%
data = data.reset_index()
data = data.drop(["index"], axis=1)

# %%
data_wahlkreise =  data.drop([index for index in list(data.index) if (data.iloc[index][2] == 99.0)])

# %%
data_wahlkreise
# Out:
#         Nr                                             Gebiet  gehört zu  \
# 0      1.0                              Flensburg – Schleswig        1.0
# 1      2.0                  Nordfriesland – Dithmarschen Nord        1.0
# 2      3.0                       Steinburg – Dithmarschen Süd        1.0
# 3      4.0                              Rendsburg-Eckernförde        1.0
# 4      5.0                                               Kiel        1.0
# 5      6.0                                  Plön – Neumünster        1.0
# 6      7.0                                          Pinneberg        1.0
# 7      8.0                          Segeberg – Stormarn-Mitte        1.0
# 8      9.0                        Ostholstein – Stormarn-Nord        1.0
# 9     10.0                 Herzogtum Lauenburg – Stormarn-Süd        1.0
# 10    11.0                                             Lübeck        1.0
# 12    12.0  Schwerin – Ludwigslust-Parchim I – Nordwestmec...       13.0
# ...

# %%
data_wahlkreise = data_wahlkreise.drop(315)

# %%
data_wahlkreise
# Out:
#         Nr                                             Gebiet  gehört zu  \
# 0      1.0                              Flensburg – Schleswig        1.0
# 1      2.0                  Nordfriesland – Dithmarschen Nord        1.0
# 2      3.0                       Steinburg – Dithmarschen Süd        1.0
# 3      4.0                              Rendsburg-Eckernförde        1.0
# 4      5.0                                               Kiel        1.0
# 5      6.0                                  Plön – Neumünster        1.0
# 6      7.0                                          Pinneberg        1.0
# 7      8.0                          Segeberg – Stormarn-Mitte        1.0
# 8      9.0                        Ostholstein – Stormarn-Nord        1.0
# 9     10.0                 Herzogtum Lauenburg – Stormarn-Süd        1.0
# 10    11.0                                             Lübeck        1.0
# 12    12.0  Schwerin – Ludwigslust-Parchim I – Nordwestmec...       13.0
# ...
