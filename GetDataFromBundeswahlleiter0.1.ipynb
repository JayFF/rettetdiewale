# %%
from bs4 import BeautifulSoup
import requests
from requests.exceptions import HTTPError
import re
import csv
#legend nur für Bundesland 1 Wahlkreis 1 Richtig
legend=["Bundesland", "Wahlkreis", "Wahlberechtigte Anzahl", "Wähler Anzahl" , "Ungültige Anzahl", "Gültige Anzahl", "CDU Anzahl", "SPD Anzahl", "Grüne Anzahl", "FDP Anzahl", "Linke Anzahl", "AfD Anzahl", "NPD Anzahl", "Freie Wähler Anzahl", "MLPD Anzahl", "BGE Anzahl", "ÖDP Anzahl", "Die PARTEI Anzahl", "EB: KrügerWinands Anzahl", "Tierschutzpartei Anzahl", "PIRATEN Anzahl", "Übrige Anzahl"]

def main():
    with open("data.csv", "w+") as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(legend)
    myfile.close()
    land = 1
    wahlkreis = 1
    toomany = 0
    while(wahlkreis<300):
        toomany+=1
        try:
            getpage = requests.get("https://www.bundeswahlleiter.de/bundestagswahlen/2017/ergebnisse/bund-99/land-%d/wahlkreis-%d.html" % (land, wahlkreis))
            getpage.raise_for_status()
        except HTTPError:
            #print("Wahlkreis %d in Bundesland %d existiert nicht" %(wahlkreis, land))
            land+=1
            if land==17:
                land = 1
            continue
        else:
            page = getpage.content
            GetData(BeautifulSoup(page, "lxml"), land, wahlkreis)
            print ("Wahlkreis %d in Bundesland %d hinzugefuegt" %(wahlkreis, land))
            wahlkreis+=1
        if toomany>2000:
            print("Too many")
            break
    print toomany
    return

# %%
def GetData(soup, land, wahlkreis):
    first_block = soup.find_all('tbody')[0]
    second_block = soup.find_all('tbody')[1]
    ErststimmenAnzahl = []
    ErststimmenProzent = []
    ErststimmenDifferenz = []
    ZweitstimmenAnzahl = []
    ZweitstimmenProzent = []
    ZweitstimmenDifferenz = []
    for row in first_block.find_all('tr'):
        cells1 = row.find_all(class_='colgroup-1 align--right')
        cells2 = row.find_all(class_='colgroup-2 align--right')
        ErststimmenAnzahl.append(cells1[0].find(text=True))
        ErststimmenProzent.append(cells1[1].find(text=True))
        ErststimmenDifferenz.append(cells1[2].find(text=True))
        ZweitstimmenAnzahl.append(cells2[0].find(text=True))
        ZweitstimmenProzent.append(cells2[1].find(text=True))
        ZweitstimmenDifferenz.append(cells2[2].find(text=True)) 
    #gleiche nochmal für den zweiten block
    for row in second_block.find_all('tr'):
        cells1 = row.find_all(class_='colgroup-1 align--right')
        cells2 = row.find_all(class_='colgroup-2 align--right')
        ErststimmenAnzahl.append(cells1[0].get_text())
        ErststimmenProzent.append(cells1[1].find(text=True))
        ErststimmenDifferenz.append(cells1[2].find(text=True))
        ZweitstimmenAnzahl.append(cells2[0].find(text=True))
        ZweitstimmenProzent.append(cells2[1].find(text=True))
        ZweitstimmenDifferenz.append(cells2[2].find(text=True))
    ErststimmenAnzahl = FormatColumnIntData(ErststimmenAnzahl)
    ErststimmenProzent = FormatColumnFloData(ErststimmenProzent)
    ErststimmenDifferenz = FormatColumnFloData(ErststimmenDifferenz)
    ZweitstimmenAnzahl = FormatColumnIntData(ZweitstimmenAnzahl)
    ZweitstimmenProzent = FormatColumnFloData(ZweitstimmenProzent)
    ZweitstimmenDifferenz = FormatColumnFloData(ZweitstimmenDifferenz)
    wahlkreisResults = []
    wahlkreisResults.append(land)
    wahlkreisResults.append(wahlkreis)
    wahlkreisResults = wahlkreisResults + ErststimmenAnzahl + ErststimmenProzent + ErststimmenDifferenz + ZweitstimmenAnzahl + ZweitstimmenProzent + ZweitstimmenDifferenz
    AddRowCSV(wahlkreisResults)
    return 
        
#Bekommt Spalte (Liste) wie ErststimmenAnzahl und macht Liste aus INTEGERS 
def FormatColumnIntData(column = []):
    newcolumn = []
    for el in range(len(column)):
        tempvar = re.findall(r'\d+.\d+', column[el])
        if tempvar:
            tempvar = tempvar[0]
            tempvar = tempvar.replace(".","")
            newcolumn.append(int(tempvar))
        else:
            newcolumn.append(None)
    return newcolumn

#Bekommt Spalte (Liste) wie ErststimmenProzent und macht Liste aus Floats 
def FormatColumnFloData(column = []):
    newcolumn = []
    for el in range(len(column)):
        #tempvar = re.findall(r'\d+.\d+', column[el])
        tempvar = re.findall(r'-?\d+.\d+', column[el])
        if tempvar:
            tempvar = tempvar[0]
            tempvar = tempvar.replace(",",".")
            newcolumn.append(float(tempvar))
        else:
            newcolumn.append(None)
    return newcolumn

def AddRowCSV(mylist = []):
    with open("data.csv", 'a') as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(mylist)
    return

if __name__ == '__main__':
    main()
# Out:
# Wahlkreis 1 in Bundesland 1 hinzugefuegt
# Wahlkreis 2 in Bundesland 1 hinzugefuegt
# Wahlkreis 3 in Bundesland 1 hinzugefuegt
# Wahlkreis 4 in Bundesland 1 hinzugefuegt
# Wahlkreis 5 in Bundesland 1 hinzugefuegt
# Wahlkreis 6 in Bundesland 1 hinzugefuegt
# Wahlkreis 7 in Bundesland 1 hinzugefuegt
# Wahlkreis 8 in Bundesland 1 hinzugefuegt
# Wahlkreis 9 in Bundesland 1 hinzugefuegt
# Wahlkreis 10 in Bundesland 1 hinzugefuegt
# Wahlkreis 11 in Bundesland 1 hinzugefuegt
# Wahlkreis 12 in Bundesland 13 hinzugefuegt
# Wahlkreis 13 in Bundesland 13 hinzugefuegt
# Wahlkreis 14 in Bundesland 13 hinzugefuegt
# Wahlkreis 15 in Bundesland 13 hinzugefuegt
# Wahlkreis 16 in Bundesland 13 hinzugefuegt
# Wahlkreis 17 in Bundesland 13 hinzugefuegt
# Wahlkreis 18 in Bundesland 2 hinzugefuegt
# Wahlkreis 19 in Bundesland 2 hinzugefuegt
# Wahlkreis 20 in Bundesland 2 hinzugefuegt
# Wahlkreis 21 in Bundesland 2 hinzugefuegt
# Wahlkreis 22 in Bundesland 2 hinzugefuegt
# Wahlkreis 23 in Bundesland 2 hinzugefuegt
# Wahlkreis 24 in Bundesland 3 hinzugefuegt
# Wahlkreis 25 in Bundesland 3 hinzugefuegt
# Wahlkreis 26 in Bundesland 3 hinzugefuegt
# Wahlkreis 27 in Bundesland 3 hinzugefuegt
# Wahlkreis 28 in Bundesland 3 hinzugefuegt
# Wahlkreis 29 in Bundesland 3 hinzugefuegt
# Wahlkreis 30 in Bundesland 3 hinzugefuegt
# Wahlkreis 31 in Bundesland 3 hinzugefuegt
# Wahlkreis 32 in Bundesland 3 hinzugefuegt
# Wahlkreis 33 in Bundesland 3 hinzugefuegt
# Wahlkreis 34 in Bundesland 3 hinzugefuegt
# Wahlkreis 35 in Bundesland 3 hinzugefuegt
# Wahlkreis 36 in Bundesland 3 hinzugefuegt
# Wahlkreis 37 in Bundesland 3 hinzugefuegt
# Wahlkreis 38 in Bundesland 3 hinzugefuegt
# Wahlkreis 39 in Bundesland 3 hinzugefuegt
# Wahlkreis 40 in Bundesland 3 hinzugefuegt
# Wahlkreis 41 in Bundesland 3 hinzugefuegt
# Wahlkreis 42 in Bundesland 3 hinzugefuegt
# Wahlkreis 43 in Bundesland 3 hinzugefuegt
# Wahlkreis 44 in Bundesland 3 hinzugefuegt
# Wahlkreis 45 in Bundesland 3 hinzugefuegt
# Wahlkreis 46 in Bundesland 3 hinzugefuegt
# Wahlkreis 47 in Bundesland 3 hinzugefuegt
# Wahlkreis 48 in Bundesland 3 hinzugefuegt
# Wahlkreis 49 in Bundesland 3 hinzugefuegt
# Wahlkreis 50 in Bundesland 3 hinzugefuegt
# Wahlkreis 51 in Bundesland 3 hinzugefuegt
# Wahlkreis 52 in Bundesland 3 hinzugefuegt
# Wahlkreis 53 in Bundesland 3 hinzugefuegt
# Wahlkreis 54 in Bundesland 4 hinzugefuegt
# Wahlkreis 55 in Bundesland 4 hinzugefuegt
# Wahlkreis 56 in Bundesland 12 hinzugefuegt
# Wahlkreis 57 in Bundesland 12 hinzugefuegt
# Wahlkreis 58 in Bundesland 12 hinzugefuegt
# Wahlkreis 59 in Bundesland 12 hinzugefuegt
# Wahlkreis 60 in Bundesland 12 hinzugefuegt
# Wahlkreis 61 in Bundesland 12 hinzugefuegt
# Wahlkreis 62 in Bundesland 12 hinzugefuegt
# Wahlkreis 63 in Bundesland 12 hinzugefuegt
# Wahlkreis 64 in Bundesland 12 hinzugefuegt
# Wahlkreis 65 in Bundesland 12 hinzugefuegt
# Wahlkreis 66 in Bundesland 15 hinzugefuegt
# Wahlkreis 67 in Bundesland 15 hinzugefuegt
# Wahlkreis 68 in Bundesland 15 hinzugefuegt
# Wahlkreis 69 in Bundesland 15 hinzugefuegt
# Wahlkreis 70 in Bundesland 15 hinzugefuegt
# Wahlkreis 71 in Bundesland 15 hinzugefuegt
# Wahlkreis 72 in Bundesland 15 hinzugefuegt
# Wahlkreis 73 in Bundesland 15 hinzugefuegt
# Wahlkreis 74 in Bundesland 15 hinzugefuegt
# Wahlkreis 75 in Bundesland 11 hinzugefuegt
# Wahlkreis 76 in Bundesland 11 hinzugefuegt
# Wahlkreis 77 in Bundesland 11 hinzugefuegt
# Wahlkreis 78 in Bundesland 11 hinzugefuegt
# Wahlkreis 79 in Bundesland 11 hinzugefuegt
# Wahlkreis 80 in Bundesland 11 hinzugefuegt
# Wahlkreis 81 in Bundesland 11 hinzugefuegt
# Wahlkreis 82 in Bundesland 11 hinzugefuegt
# Wahlkreis 83 in Bundesland 11 hinzugefuegt
# Wahlkreis 84 in Bundesland 11 hinzugefuegt
# Wahlkreis 85 in Bundesland 11 hinzugefuegt
# Wahlkreis 86 in Bundesland 11 hinzugefuegt
# Wahlkreis 87 in Bundesland 5 hinzugefuegt
# Wahlkreis 88 in Bundesland 5 hinzugefuegt
# Wahlkreis 89 in Bundesland 5 hinzugefuegt
# Wahlkreis 90 in Bundesland 5 hinzugefuegt
# Wahlkreis 91 in Bundesland 5 hinzugefuegt
# Wahlkreis 92 in Bundesland 5 hinzugefuegt
# Wahlkreis 93 in Bundesland 5 hinzugefuegt
# Wahlkreis 94 in Bundesland 5 hinzugefuegt
# Wahlkreis 95 in Bundesland 5 hinzugefuegt
# Wahlkreis 96 in Bundesland 5 hinzugefuegt
# Wahlkreis 97 in Bundesland 5 hinzugefuegt
# Wahlkreis 98 in Bundesland 5 hinzugefuegt
# Wahlkreis 99 in Bundesland 5 hinzugefuegt
# Wahlkreis 100 in Bundesland 5 hinzugefuegt
# Wahlkreis 101 in Bundesland 5 hinzugefuegt
# Wahlkreis 102 in Bundesland 5 hinzugefuegt
# Wahlkreis 103 in Bundesland 5 hinzugefuegt
# Wahlkreis 104 in Bundesland 5 hinzugefuegt
# Wahlkreis 105 in Bundesland 5 hinzugefuegt
# Wahlkreis 106 in Bundesland 5 hinzugefuegt
# Wahlkreis 107 in Bundesland 5 hinzugefuegt
# Wahlkreis 108 in Bundesland 5 hinzugefuegt
# Wahlkreis 109 in Bundesland 5 hinzugefuegt
# Wahlkreis 110 in Bundesland 5 hinzugefuegt
# Wahlkreis 111 in Bundesland 5 hinzugefuegt
# Wahlkreis 112 in Bundesland 5 hinzugefuegt
# Wahlkreis 113 in Bundesland 5 hinzugefuegt
# Wahlkreis 114 in Bundesland 5 hinzugefuegt
# Wahlkreis 115 in Bundesland 5 hinzugefuegt
# Wahlkreis 116 in Bundesland 5 hinzugefuegt
# Wahlkreis 117 in Bundesland 5 hinzugefuegt
# Wahlkreis 118 in Bundesland 5 hinzugefuegt
# Wahlkreis 119 in Bundesland 5 hinzugefuegt
# Wahlkreis 120 in Bundesland 5 hinzugefuegt
# Wahlkreis 121 in Bundesland 5 hinzugefuegt
# Wahlkreis 122 in Bundesland 5 hinzugefuegt
# Wahlkreis 123 in Bundesland 5 hinzugefuegt
# Wahlkreis 124 in Bundesland 5 hinzugefuegt
# Wahlkreis 125 in Bundesland 5 hinzugefuegt
# Wahlkreis 126 in Bundesland 5 hinzugefuegt
# Wahlkreis 127 in Bundesland 5 hinzugefuegt
# Wahlkreis 128 in Bundesland 5 hinzugefuegt
# Wahlkreis 129 in Bundesland 5 hinzugefuegt
# Wahlkreis 130 in Bundesland 5 hinzugefuegt
# Wahlkreis 131 in Bundesland 5 hinzugefuegt
# Wahlkreis 132 in Bundesland 5 hinzugefuegt
# Wahlkreis 133 in Bundesland 5 hinzugefuegt
# Wahlkreis 134 in Bundesland 5 hinzugefuegt
# Wahlkreis 135 in Bundesland 5 hinzugefuegt
# Wahlkreis 136 in Bundesland 5 hinzugefuegt
# Wahlkreis 137 in Bundesland 5 hinzugefuegt
# Wahlkreis 138 in Bundesland 5 hinzugefuegt
# Wahlkreis 139 in Bundesland 5 hinzugefuegt
# Wahlkreis 140 in Bundesland 5 hinzugefuegt
# Wahlkreis 141 in Bundesland 5 hinzugefuegt
# Wahlkreis 142 in Bundesland 5 hinzugefuegt
# Wahlkreis 143 in Bundesland 5 hinzugefuegt
# Wahlkreis 144 in Bundesland 5 hinzugefuegt
# Wahlkreis 145 in Bundesland 5 hinzugefuegt
# Wahlkreis 146 in Bundesland 5 hinzugefuegt
# Wahlkreis 147 in Bundesland 5 hinzugefuegt
# Wahlkreis 148 in Bundesland 5 hinzugefuegt
# Wahlkreis 149 in Bundesland 5 hinzugefuegt
# Wahlkreis 150 in Bundesland 5 hinzugefuegt
# Wahlkreis 151 in Bundesland 14 hinzugefuegt
# Wahlkreis 152 in Bundesland 14 hinzugefuegt
# Wahlkreis 153 in Bundesland 14 hinzugefuegt
# Wahlkreis 154 in Bundesland 14 hinzugefuegt
# Wahlkreis 155 in Bundesland 14 hinzugefuegt
# Wahlkreis 156 in Bundesland 14 hinzugefuegt
# Wahlkreis 157 in Bundesland 14 hinzugefuegt
# Wahlkreis 158 in Bundesland 14 hinzugefuegt
# Wahlkreis 159 in Bundesland 14 hinzugefuegt
# Wahlkreis 160 in Bundesland 14 hinzugefuegt
# Wahlkreis 161 in Bundesland 14 hinzugefuegt
# Wahlkreis 162 in Bundesland 14 hinzugefuegt
# Wahlkreis 163 in Bundesland 14 hinzugefuegt
# Wahlkreis 164 in Bundesland 14 hinzugefuegt
# Wahlkreis 165 in Bundesland 14 hinzugefuegt
# Wahlkreis 166 in Bundesland 14 hinzugefuegt
# Wahlkreis 167 in Bundesland 6 hinzugefuegt
# Wahlkreis 168 in Bundesland 6 hinzugefuegt
# Wahlkreis 169 in Bundesland 6 hinzugefuegt
# Wahlkreis 170 in Bundesland 6 hinzugefuegt
# Wahlkreis 171 in Bundesland 6 hinzugefuegt
# Wahlkreis 172 in Bundesland 6 hinzugefuegt
# Wahlkreis 173 in Bundesland 6 hinzugefuegt
# Wahlkreis 174 in Bundesland 6 hinzugefuegt
# Wahlkreis 175 in Bundesland 6 hinzugefuegt
# Wahlkreis 176 in Bundesland 6 hinzugefuegt
# Wahlkreis 177 in Bundesland 6 hinzugefuegt
# Wahlkreis 178 in Bundesland 6 hinzugefuegt
# Wahlkreis 179 in Bundesland 6 hinzugefuegt
# Wahlkreis 180 in Bundesland 6 hinzugefuegt
# Wahlkreis 181 in Bundesland 6 hinzugefuegt
# Wahlkreis 182 in Bundesland 6 hinzugefuegt
# Wahlkreis 183 in Bundesland 6 hinzugefuegt
# Wahlkreis 184 in Bundesland 6 hinzugefuegt
# Wahlkreis 185 in Bundesland 6 hinzugefuegt
# Wahlkreis 186 in Bundesland 6 hinzugefuegt
# Wahlkreis 187 in Bundesland 6 hinzugefuegt
# Wahlkreis 188 in Bundesland 6 hinzugefuegt
# Wahlkreis 189 in Bundesland 16 hinzugefuegt
# Wahlkreis 190 in Bundesland 16 hinzugefuegt
# Wahlkreis 191 in Bundesland 16 hinzugefuegt
# Wahlkreis 192 in Bundesland 16 hinzugefuegt
# Wahlkreis 193 in Bundesland 16 hinzugefuegt
# Wahlkreis 194 in Bundesland 16 hinzugefuegt
# Wahlkreis 195 in Bundesland 16 hinzugefuegt
# Wahlkreis 196 in Bundesland 16 hinzugefuegt
# Wahlkreis 197 in Bundesland 7 hinzugefuegt
# Wahlkreis 198 in Bundesland 7 hinzugefuegt
# Wahlkreis 199 in Bundesland 7 hinzugefuegt
# Wahlkreis 200 in Bundesland 7 hinzugefuegt
# Wahlkreis 201 in Bundesland 7 hinzugefuegt
# Wahlkreis 202 in Bundesland 7 hinzugefuegt
# Wahlkreis 203 in Bundesland 7 hinzugefuegt
# Wahlkreis 204 in Bundesland 7 hinzugefuegt
# Wahlkreis 205 in Bundesland 7 hinzugefuegt
# Wahlkreis 206 in Bundesland 7 hinzugefuegt
# Wahlkreis 207 in Bundesland 7 hinzugefuegt
# Wahlkreis 208 in Bundesland 7 hinzugefuegt
# Wahlkreis 209 in Bundesland 7 hinzugefuegt
# Wahlkreis 210 in Bundesland 7 hinzugefuegt
# Wahlkreis 211 in Bundesland 7 hinzugefuegt
# Wahlkreis 212 in Bundesland 9 hinzugefuegt
# Wahlkreis 213 in Bundesland 9 hinzugefuegt
# Wahlkreis 214 in Bundesland 9 hinzugefuegt
# Wahlkreis 215 in Bundesland 9 hinzugefuegt
# Wahlkreis 216 in Bundesland 9 hinzugefuegt
# Wahlkreis 217 in Bundesland 9 hinzugefuegt
# Wahlkreis 218 in Bundesland 9 hinzugefuegt
# Wahlkreis 219 in Bundesland 9 hinzugefuegt
# Wahlkreis 220 in Bundesland 9 hinzugefuegt
# Wahlkreis 221 in Bundesland 9 hinzugefuegt
# Wahlkreis 222 in Bundesland 9 hinzugefuegt
# Wahlkreis 223 in Bundesland 9 hinzugefuegt
# Wahlkreis 224 in Bundesland 9 hinzugefuegt
# Wahlkreis 225 in Bundesland 9 hinzugefuegt
# Wahlkreis 226 in Bundesland 9 hinzugefuegt
# Wahlkreis 227 in Bundesland 9 hinzugefuegt
# Wahlkreis 228 in Bundesland 9 hinzugefuegt
# Wahlkreis 229 in Bundesland 9 hinzugefuegt
# Wahlkreis 230 in Bundesland 9 hinzugefuegt
# Wahlkreis 231 in Bundesland 9 hinzugefuegt
# Wahlkreis 232 in Bundesland 9 hinzugefuegt
# Wahlkreis 233 in Bundesland 9 hinzugefuegt
# Wahlkreis 234 in Bundesland 9 hinzugefuegt
# Wahlkreis 235 in Bundesland 9 hinzugefuegt
# Wahlkreis 236 in Bundesland 9 hinzugefuegt
# Wahlkreis 237 in Bundesland 9 hinzugefuegt
# Wahlkreis 238 in Bundesland 9 hinzugefuegt
# Wahlkreis 239 in Bundesland 9 hinzugefuegt
# Wahlkreis 240 in Bundesland 9 hinzugefuegt
# Wahlkreis 241 in Bundesland 9 hinzugefuegt
# Wahlkreis 242 in Bundesland 9 hinzugefuegt
# Wahlkreis 243 in Bundesland 9 hinzugefuegt
# Wahlkreis 244 in Bundesland 9 hinzugefuegt
# Wahlkreis 245 in Bundesland 9 hinzugefuegt
# Wahlkreis 246 in Bundesland 9 hinzugefuegt
# Wahlkreis 247 in Bundesland 9 hinzugefuegt
# Wahlkreis 248 in Bundesland 9 hinzugefuegt
# Wahlkreis 249 in Bundesland 9 hinzugefuegt
# Wahlkreis 250 in Bundesland 9 hinzugefuegt
# Wahlkreis 251 in Bundesland 9 hinzugefuegt
# Wahlkreis 252 in Bundesland 9 hinzugefuegt
# Wahlkreis 253 in Bundesland 9 hinzugefuegt
# Wahlkreis 254 in Bundesland 9 hinzugefuegt
# Wahlkreis 255 in Bundesland 9 hinzugefuegt
# Wahlkreis 256 in Bundesland 9 hinzugefuegt
# Wahlkreis 257 in Bundesland 9 hinzugefuegt
# Wahlkreis 258 in Bundesland 8 hinzugefuegt
# Wahlkreis 259 in Bundesland 8 hinzugefuegt
# Wahlkreis 260 in Bundesland 8 hinzugefuegt
# Wahlkreis 261 in Bundesland 8 hinzugefuegt
# Wahlkreis 262 in Bundesland 8 hinzugefuegt
# Wahlkreis 263 in Bundesland 8 hinzugefuegt
# Wahlkreis 264 in Bundesland 8 hinzugefuegt
# Wahlkreis 265 in Bundesland 8 hinzugefuegt
# Wahlkreis 266 in Bundesland 8 hinzugefuegt
# Wahlkreis 267 in Bundesland 8 hinzugefuegt
# Wahlkreis 268 in Bundesland 8 hinzugefuegt
# Wahlkreis 269 in Bundesland 8 hinzugefuegt
# Wahlkreis 270 in Bundesland 8 hinzugefuegt
# Wahlkreis 271 in Bundesland 8 hinzugefuegt
# Wahlkreis 272 in Bundesland 8 hinzugefuegt
# Wahlkreis 273 in Bundesland 8 hinzugefuegt
# Wahlkreis 274 in Bundesland 8 hinzugefuegt
# Wahlkreis 275 in Bundesland 8 hinzugefuegt
# Wahlkreis 276 in Bundesland 8 hinzugefuegt
# Wahlkreis 277 in Bundesland 8 hinzugefuegt
# Wahlkreis 278 in Bundesland 8 hinzugefuegt
# Wahlkreis 279 in Bundesland 8 hinzugefuegt
# Wahlkreis 280 in Bundesland 8 hinzugefuegt
# Wahlkreis 281 in Bundesland 8 hinzugefuegt
# Wahlkreis 282 in Bundesland 8 hinzugefuegt
# Wahlkreis 283 in Bundesland 8 hinzugefuegt
# Wahlkreis 284 in Bundesland 8 hinzugefuegt
# Wahlkreis 285 in Bundesland 8 hinzugefuegt
# Wahlkreis 286 in Bundesland 8 hinzugefuegt
# Wahlkreis 287 in Bundesland 8 hinzugefuegt
# Wahlkreis 288 in Bundesland 8 hinzugefuegt
# Wahlkreis 289 in Bundesland 8 hinzugefuegt
# Wahlkreis 290 in Bundesland 8 hinzugefuegt
# Wahlkreis 291 in Bundesland 8 hinzugefuegt
# Wahlkreis 292 in Bundesland 8 hinzugefuegt
# Wahlkreis 293 in Bundesland 8 hinzugefuegt
# Wahlkreis 294 in Bundesland 8 hinzugefuegt
# Wahlkreis 295 in Bundesland 8 hinzugefuegt
# Wahlkreis 296 in Bundesland 10 hinzugefuegt
# Wahlkreis 297 in Bundesland 10 hinzugefuegt
# Wahlkreis 298 in Bundesland 10 hinzugefuegt
# Wahlkreis 299 in Bundesland 10 hinzugefuegt
# 404
