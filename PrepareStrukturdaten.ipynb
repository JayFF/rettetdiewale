# %%
import pandas as pd
import re
data = pd.read_csv("btw17_strukturdaten.csv",";", encoding='latin1')

# %%
data
# Out:
#               # © Der Bundeswahlleiter, Wiesbaden 2017     Unnamed: 1  \
# 0    # Quelle der Rohdaten der Spalten 35 bis 48: ©...            NaN
# 1                                                   #             NaN
# 2    # Strukturdaten für die Wahlkreise zum 19. Deu...            NaN
# 3                                                   #             NaN
# 4     # Zeichensatz: CP 1252. Trennzeichen: Semikolon.            NaN
# 5                                                    #            NaN
# 6                                          Spalten-Nr.            NaN
# 7                                                 Land  Wahlkreis-Nr.
# 8                                   Schleswig-Holstein              1
# 9                                   Schleswig-Holstein              2
# 10                                  Schleswig-Holstein              3
# 11                                  Schleswig-Holstein              4
# ...
